# %%
import nibabel as nib
import linc_convert
from linc_convert.utils.zarr_config import GeneralConfig

# %%
import os
import sys
# add the path to the stitch directory
sys.path.append('/space/megaera/1/users/kchai/code/oct-pipe')
from stitch import fit_coord_files, generate_mask

# %%
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.yaml',base_dir = '/space/zircon/5/users/kchai/I55_slice5/analysis/processed')
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.jpeg', )
# Out:
# 2025-12-08 11:22:07,380 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:22:07,470 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.yaml
#   - Processed 434 tiles
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:00<00:00, 582.49it/s]
# 2025-12-08 11:22:08,217 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:22:14,768 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.nii
# 2025-12-08 11:22:16,151 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# 2025-12-08 11:22:16,151 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving JPEG preview: /space/zircon/5/users/kchai/I55_stitch/mosaic_001_aip.jpeg
# ...

# %%
generate_mask.main(input='/space/zircon/5/users/kchai/I55_stitch/slice5_aip.nii', output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii', threshold=60)
# Out:
# Loading input from /space/zircon/5/users/kchai/I55_stitch/slice5_aip.nii...
#   Shape: (4176, 8902), dtype: float32, range: [nan, nan]
# Applying Gaussian filter (sigma=1.0)...
#   Filtered range: [nan, nan]
# Creating binary mask with threshold=60...
#   Foreground pixels: 15608231, Background pixels: 21566521
# Ensuring single connected component...
#   After single component: Foreground pixels: 15605295, Background pixels: 21569457
# Saving mask to /space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii...
# Done!

# %%
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ret.yaml', base_dir = '/space/zircon/5/users/kchai/I55_slice5/analysis/processed', mask = '/space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii', filepath_replacements = {'aip':'ret'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ret.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ret.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ret.jpeg')
# Out:
# 2025-12-08 10:31:57,989 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 10:31:58,078 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_001_ret.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 2 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:00<00:00, 1188.43it/s]
# 2025-12-08 10:31:58,445 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 10:32:01,092 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and applying mask: /space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii
# 2025-12-08 10:32:01,429 - linc_convert.modalities.psoct.mosaic2d - INFO - Mask applied successfully
# ...

# %%
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ori.yaml',base_dir = '/space/zircon/5/users/kchai/I55_slice5/analysis/processed', mask = '/space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii', filepath_replacements = {'aip':'ori'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ori.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ori.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_001_ori.jpeg',circular_mean=True)
# Out:
# 2025-12-08 10:32:53,487 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 10:32:53,576 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_001_ori.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 2 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:01<00:00, 394.66it/s]
# 2025-12-08 10:32:54,678 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 10:32:58,313 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and applying mask: /space/zircon/5/users/kchai/I55_stitch/mosaic_001_mask.nii
# 2025-12-08 10:32:58,600 - linc_convert.modalities.psoct.mosaic2d - INFO - Mask applied successfully
# ---------------------------------------------------------------------------
# ...

# %%
# lets do retardance and intensity first and take care of orientation later

# %%
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.yaml',base_dir = '/space/zircon/5/users/kchai/I55_slice6/analysis/processed', filepath_replacements = {'mosaic_001':'mosaic_003'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.jpeg', )
generate_mask.main(input='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.nii', output='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_mask.nii', threshold=60)
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_ret.yaml', base_dir = '/space/zircon/5/users/kchai/I55_slice6/analysis/processed', mask = '/space/zircon/5/users/kchai/I55_stitch/mosaic_003_mask.nii', filepath_replacements = {'aip':'ret', 'mosaic_001':'mosaic_003'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_ret.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_ret.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_003_ret.jpeg')
# Out:
# 2025-12-08 11:22:29,384 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:22:29,474 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:01<00:00, 272.09it/s]
# 2025-12-08 11:22:31,070 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:22:38,044 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_003_aip.nii
# 2025-12-08 11:22:39,430 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# ...

# %%
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.yaml',base_dir = '/space/zircon/5/users/kchai/I55_slice6/analysis/processed', filepath_replacements = {'mosaic_001':'mosaic_005'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.jpeg', )
generate_mask.main(input='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.nii', output='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_mask.nii', threshold=60)
fit_coord_files.convert_yaml_format(input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml', output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_ret.yaml', base_dir = '/space/zircon/5/users/kchai/I55_slice6/analysis/processed', mask = '/space/zircon/5/users/kchai/I55_stitch/mosaic_005_mask.nii', filepath_replacements = {'aip':'ret', 'mosaic_001':'mosaic_005'})
linc_convert.modalities.psoct.mosaic2d.mosaic2d(tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_ret.yaml', nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_ret.nii', jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_005_ret.jpeg')
# Out:
# 2025-12-08 11:50:42,635 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:50:42,725 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:00<00:00, 600.60it/s]
# 2025-12-08 11:50:43,450 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:50:50,234 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_005_aip.nii
# 2025-12-08 11:50:51,712 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# ...

# %%
# ---- mosaic 007 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_007'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_007'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_007_ret.jpeg',
)

# ---- mosaic 009 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_009'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_009'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_009_ret.jpeg',
)

# ---- mosaic 011 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_011'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_011'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_011_ret.jpeg',
)

# ---- mosaic 013 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_013'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice6/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_013'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_013_ret.jpeg',
)
# Out:
# 2025-12-08 11:26:01,291 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:26:01,380 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:01<00:00, 260.96it/s]
# 2025-12-08 11:26:03,045 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:26:10,211 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_007_aip.nii
# 2025-12-08 11:26:11,504 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# ...

# %%
# ---- mosaic 015 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice12/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_015'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice12/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_015'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_015_ret.jpeg',
)
# ---- mosaic 017 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice13/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_017'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice13/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_017'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_017_ret.jpeg',
)

# ---- mosaic 019 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice14/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_019'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice14/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_019'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_019_ret.jpeg',
)

# ---- mosaic 021 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice15/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_021'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice15/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_021'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_021_ret.jpeg',
)

# ---- mosaic 023 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice16/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_023'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice16/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_023'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_023_ret.jpeg',
)
# Out:
# 2025-12-08 11:37:44,364 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:37:44,450 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:07<00:00, 61.05it/s]
# 2025-12-08 11:37:51,561 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:37:58,533 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_015_aip.nii
# 2025-12-08 11:37:59,825 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# ...

# %%
# ---- mosaic 025 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice17/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_025'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice17/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_025'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_025_ret.jpeg',
)


# ---- mosaic 027 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice18/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_027'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice18/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_027'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_027_ret.jpeg',
)


# ---- mosaic 029 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice19/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_029'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice19/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_029'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_029_ret.jpeg',
)


# ---- mosaic 031 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice20/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_031'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice20/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_031'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_031_ret.jpeg',
)


# ---- mosaic 033 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice21/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_033'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice21/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_033'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_033_ret.jpeg',
)


# ---- mosaic 035 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice22/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_035'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice22/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_035'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_035_ret.jpeg',
)


# ---- mosaic 037 ----
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_aip.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice23/analysis/processed',
    filepath_replacements={'mosaic_001': 'mosaic_037'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_aip.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_aip.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_aip.jpeg',
)
generate_mask.main(
    input='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_aip.nii',
    output='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_mask.nii',
    threshold=60
)
fit_coord_files.convert_yaml_format(
    input_path='/space/zircon/5/users/kchai/I55_stitch/Normal.yaml',
    output_path='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_ret.yaml',
    base_dir='/space/zircon/5/users/kchai/I55_slice23/analysis/processed',
    mask='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_mask.nii',
    filepath_replacements={'aip': 'ret', 'mosaic_001': 'mosaic_037'}
)
linc_convert.modalities.psoct.mosaic2d.mosaic2d(
    tile_info_file='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_ret.yaml',
    nifti_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_ret.nii',
    jpeg_output='/space/zircon/5/users/kchai/I55_stitch/mosaic_037_ret.jpeg',
)
# Out:
# 2025-12-08 11:56:30,931 - linc_convert.modalities.psoct.mosaic2d - INFO - Started mosaic2d
# 2025-12-08 11:56:31,019 - linc_convert.modalities.psoct.mosaic2d - INFO - Loading and processing 434 tiles
# Successfully converted /space/zircon/5/users/kchai/I55_stitch/Normal.yaml to /space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.yaml
#   - Processed 434 tiles
#   - Applied 1 filepath replacements
#   - Added 1 metadata fields
# Processing tiles: 100%|██████████| 434/434 [00:07<00:00, 58.98it/s]
# 2025-12-08 11:56:38,378 - linc_convert.modalities.psoct.mosaic2d - INFO - Stitching tiles
# 2025-12-08 11:56:45,698 - linc_convert.modalities.psoct.mosaic2d - INFO - Saving NIfTI file: /space/zircon/5/users/kchai/I55_stitch/mosaic_025_aip.nii
# 2025-12-08 11:56:52,923 - linc_convert.modalities.psoct.mosaic2d - INFO - NIfTI file saved successfully
# ...

# %%
import numpy as np
slices = []
for i in range(1, 38, 2):  # 1,3,5,...,37
    nii_path = f'/space/zircon/5/users/kchai/I55_stitch/mosaic_{i:03d}_aip.nii'
    slices.append(nib.load(nii_path).get_fdata())

# %%
slices[0].shape
# Out:
# (4176, 8902)

# %%
vol=np.stack(slices, axis=2)

# %%
vol=vol.astype(np.float32)

# %%
voxel_sizes = (0.01, 0.5, 0.01)  # in mm, which is 10, 10, 500 micron

# %%
image = nib.Nifti1Image(vol, np.eye(4))
image.header.set_zooms(voxel_sizes)

# %%
vol = vol.transpose(0,2,1)
vol = vol[::-1,:,::-1]

# %%
ras_affine = np.eye(4)
image_ras = nib.Nifti1Image(vol, ras_affine)
image_ras.header.set_zooms(voxel_sizes)
nib.save(image_ras, '/space/megaera/3/users/kchai/mosaic_all_aip.nii')

# %%
ref_image = nib.load('/autofs/space/nyx_002/users/tgong/Microstructure/data/I55_slab4/dmri.te1/dwi_biascorr_las.nii.gz')

# %%
ref_image.affine
# Out:
# array([[-0.5,  0. ,  0. , 50. ],
#        [ 0. ,  0.5,  0. ,  0.5],
#        [ 0. ,  0. ,  0.5,  0. ],
#        [ 0. ,  0. ,  0. ,  1. ]])

# %%
nib.save(image, '/space/megaera/3/users/kchai/mosaic_all_aip.nii')

# %%
run("Grid/Collection stitching", "type=[Grid: snake by columns] order=[Up & Right] grid_size_x=14 grid_size_y=31 tile_overlap=20 first_file_index_i=1 directory=/autofs/space/zircon_005/users/kchai/I55_slice5/analysis/processed file_names=mosaic_001_image_{iii}_processed_aip.nii output_textfile_name=TileConfigurationAll.txt fusion_method=[Linear Blending] regression_threshold=0.30 max/avg_displacement_threshold=2.50 absolute_displacement_threshold=3.50 compute_overlap computation_parameters=[Save computation time (but use more RAM)] image_output=[Fuse and display]");
run("Grid/Collection stitching", "type=[Grid: snake by columns] order=[Up & Right] grid_size_x=14 grid_size_y=31 tile_overlap=20 first_file_index_i=1 directory=/autofs/space/zircon_005/users/kchai/I55_slice5/analysis/processed file_names=mosaic_001_image_{iii}_processed_aip.nii output_textfile_name=TileConfigurationAll.txt fusion_method=[Do not fuse images (only write TileConfiguration)] regression_threshold=0.30 max/avg_displacement_threshold=2.50 absolute_displacement_threshold=3.50 compute_overlap computation_parameters=[Save computation time (but use more RAM)] image_output=[Fuse and display]");

# %%
from tifffile import imread
import numpy as np

# List of paths for mosaic AIP TIFFs across slices
tif_paths = [
    '/space/zircon/5/users/kchai/I55_slice5/analysis/mosaic_001_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_003_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_005_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_007_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_009_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_011_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_013_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice12/analysis/mosaic_015_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice13/analysis/mosaic_017_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice14/analysis/mosaic_019_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice15/analysis/mosaic_021_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice16/analysis/mosaic_023_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice17/analysis/mosaic_025_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice18/analysis/mosaic_027_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice19/analysis/mosaic_029_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice20/analysis/mosaic_031_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice21/analysis/mosaic_033_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice22/analysis/mosaic_035_aip.tif',
    '/space/zircon/5/users/kchai/I55_slice23/analysis/mosaic_037_aip.tif'
]

# Read and stack TIFFs (assume 2D images, shape=(y,x))
images = [imread(p) for p in tif_paths]

# %%
images = np.stack(images, axis=2)

# %%
images=images.transpose(1,2,0)

# %%
images= images[::-1,:,::-1]

# %%
header= np.eye(4)
header[0,0] = voxel_sizes[0]
header[1,1] = voxel_sizes[1]
header[2,2] = voxel_sizes[2]
image = nib.Nifti1Image(images, header)
nib.save(image, '/scratch/mosaic_all_aip.nii')

# %%
import numpy as np
import nibabel as nib
from nibabel.affines import apply_affine
def align_centers_affine(moving_nii, fixed_nii):
    """
    Aligns the center of the moving_nii to the center of the fixed_nii 
    by modifying the affine matrix of the moving image.
    
    This function does NOT resample the image data; it only changes the 
    spatial definition (header) of the moving image.

    Parameters:
    -----------
    moving_nii : nibabel.nifti1.Nifti1Image
        The image to be shifted.
    fixed_nii : nibabel.nifti1.Nifti1Image
        The reference image defining the target center.

    Returns:
    --------
    nibabel.nifti1.Nifti1Image
        A new NIfTI image with the same data as moving_nii but a modified affine.
    """
    
    # 1. Calculate the geometric center in Voxel Space for both images
    # The center of a volume with N voxels is typically at (N - 1) / 2
    moving_shape = moving_nii.shape[:3]
    fixed_shape = fixed_nii.shape[:3]
    
    moving_center_vox = np.array([(n - 1) / 2.0 for n in moving_shape])
    fixed_center_vox = np.array([(n - 1) / 2.0 for n in fixed_shape])

    # 2. Convert Voxel Centers to World Coordinates using existing affines
    # We append 1 to the voxel coordinates to perform matrix multiplication
    # Affine dot [x, y, z, 1] -> [x_world, y_world, z_world, 1]
    
    moving_affine = moving_nii.affine
    fixed_affine = fixed_nii.affine
    
    # nib.affines.apply_affine is a helper to do (Affine * coord)[:3]
    moving_center_world = nib.affines.apply_affine(moving_affine, moving_center_vox)
    fixed_center_world = nib.affines.apply_affine(fixed_affine, fixed_center_vox)

    # 3. Calculate the translation vector required
    # Vector = Target - Current
    translation = fixed_center_world - moving_center_world

    # 4. Create the new affine
    # We copy the old affine and simply add the translation to the last column
    new_affine = moving_affine.copy()
    new_affine[:3, 3] += translation
    # 5. Create new NIfTI object
    # We use the original data object (no resampling) and the new affine
    shifted_img = nib.Nifti1Image(moving_nii.dataobj, new_affine)
    # shifted_img.header.set_zooms(moving_nii.header.get_zooms())
    return shifted_img

# %%
shifted_img = align_centers_affine(image, ref_image)

# %%
nib.save(align_centers_affine(image, ref_image), '/scratch/sub-I55_aip.nii')

# %%
# %%
import nibabel as nib
import linc_convert
from linc_convert.utils.zarr_config import GeneralConfig

from tifffile import imread
import numpy as np

# List of paths for mosaic ret TIFFs across slices
tif_paths = [
    '/space/zircon/5/users/kchai/I55_slice5/analysis/mosaic_001_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_003_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_005_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_007_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_009_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_011_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/mosaic_013_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice12/analysis/mosaic_015_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice13/analysis/mosaic_017_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice14/analysis/mosaic_019_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice15/analysis/mosaic_021_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice16/analysis/mosaic_023_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice17/analysis/mosaic_025_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice18/analysis/mosaic_027_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice19/analysis/mosaic_029_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice20/analysis/mosaic_031_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice21/analysis/mosaic_033_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice22/analysis/mosaic_035_ret.tif',
    '/space/zircon/5/users/kchai/I55_slice23/analysis/mosaic_037_ret.tif'
]

# Read and stack TIFFs (assume 2D images, shape=(y,x))
images = [imread(p) for p in tif_paths]

ref_image = nib.load('/autofs/space/nyx_002/users/tgong/Microstructure/data/I55_slab4/dmri.te1/dwi_biascorr_las.nii.gz')

# %%
images = np.stack(images, axis=2)

# %%
images=images.transpose(1,2,0)

voxel_sizes = (0.01, 0.5, 0.01)  # in mm, which is 10, 10, 500 micron


# %%
images= images[::-1,:,::-1]
images = np.where(mask, images, 0)
# %%
header= np.eye(4)
header[0,0] = voxel_sizes[0]
header[1,1] = voxel_sizes[1]
header[2,2] = voxel_sizes[2]
image = nib.Nifti1Image(images, header)

# %%
shifted_img = align_centers_affine(image, ref_image)

# %%
nib.save(align_centers_affine(image, ref_image), '/scratch/sub-I55_ret.nii')

# %%
from dask_image.imread import imread

# %%
# 

import math
from PIL import Image
# For each mosaic, load the corresponding 3daxis JPEG (analysis/processed/3daxis{mosaic_index//2+1}.jpg)
jpeg_paths = []
for tif_path in tif_paths:
    # Parse the mosaic_XXX part
    base = tif_path.split('/')[-1]  # mosaic_XXX_ret.tif
    mosaic_num = int(base.split('_')[1])
    jpeg_idx = mosaic_num // 2 + 1
    jpeg_path = tif_path.replace('analysis/mosaic_' + f'{mosaic_num:03d}' + '_ret.tif',
                                 f'analysis/processed/3daxis{jpeg_idx}.jpg')
    jpeg_paths.append(jpeg_path)
imgs = []
# Optional: Load and show all JPEG previews as a check
for i, jpeg_path in enumerate(jpeg_paths):
    try:
        
        imgs.append(imread(jpeg_path))
    except FileNotFoundError:
        print(f"JPEG not found: {jpeg_path}")

# %%
import dask.array as da
img =da.stack(imgs,axis=0)

# %%
img = img.reshape(19,8750,3990,3)
img = img.transpose(2,0,1,3)
img = img[::-1,:,::-1,:]
img = img.compute()
affine = np.eye(4)
affine[0,0] = voxel_sizes[0]
affine[1,1] = voxel_sizes[1]
affine[2,2] = voxel_sizes[2]

# %%
from scipy.ndimage import gaussian_filter
from scipy import ndimage
intensity = nib.load('/scratch/sub-I55_aip.nii')
intensity = intensity.get_fdata()
# apply gaussian filter to intensity
intensity = gaussian_filter(intensity, sigma=3)
mask = intensity > 60

def ensure_single_component(
    mask: np.ndarray,
    keep_largest: bool = True
) -> np.ndarray:
    """
    Ensure mask has only one connected component for background and object.
    
    Parameters
    ----------
    mask : np.ndarray
        Binary mask
    keep_largest : bool
        If True, keep the largest component. If False, keep the component
        that contains the center of the image.
        
    Returns
    -------
    mask : np.ndarray
        Mask with only one connected component
    """
    # Label connected components
    labeled_mask, num_features = ndimage.label(mask)
    
    if num_features <= 1:
        # Already has one or zero components
        return mask
    
    if keep_largest:
        # Find the largest component
        component_sizes = ndimage.sum(mask, labeled_mask, range(1, num_features + 1))
        largest_component = np.argmax(component_sizes) + 1
        result = (labeled_mask == largest_component).astype(np.uint8)
    else:
        # Keep the component that contains the center
        center = tuple(s // 2 for s in mask.shape)
        center_label = labeled_mask[center]
        if center_label == 0:
            # Center is background, find largest background component
            labeled_bg, num_bg = ndimage.label(~mask.astype(bool))
            if num_bg > 1:
                bg_sizes = ndimage.sum(~mask.astype(bool), labeled_bg, range(1, num_bg + 1))
                largest_bg = np.argmax(bg_sizes) + 1
                # Keep everything except the largest background component
                result = mask.copy()
                result[labeled_bg == largest_bg] = 1
            else:
                result = mask
        else:
            result = (labeled_mask == center_label).astype(np.uint8)
    
    # Also ensure background has only one component
    labeled_bg, num_bg = ndimage.label(~result.astype(bool))
    if num_bg > 1:
        # Find the largest background component (usually the outer one)
        bg_sizes = ndimage.sum(~result.astype(bool), labeled_bg, range(1, num_bg + 1))
        largest_bg = np.argmax(bg_sizes) + 1
        # Set all other background components to foreground
        result[labeled_bg != largest_bg] = 1
        result[labeled_bg == largest_bg] = 0
    
    return result.astype(np.uint8)

mask = ensure_single_component(mask)

# %%
img=img.astype(np.uint8)

# %%
img.sum()
# Out:
# np.uint64(181478668334)

# %%
img = np.where(mask[...,None], img, 0)

vol = nib.Nifti1Image(img, affine, dtype=np.uint8)
vol = align_centers_affine(vol, ref_image)

nib.save(vol, '/scratch/sub-I55_axis.nii')

# %%
# %%
import nibabel as nib
import linc_convert
from linc_convert.utils.zarr_config import GeneralConfig

import numpy as np

# List of paths for mosaic ret TIFFs across slices
tif_paths = [
    '/space/zircon/5/users/kchai/I55_slice5/analysis/3daxis1.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis2.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis3.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis4.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis5.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis6.nii',
    '/space/zircon/5/users/kchai/I55_slice6/analysis/3daxis7.nii',
    '/space/zircon/5/users/kchai/I55_slice12/analysis/3daxis8.nii',
    '/space/zircon/5/users/kchai/I55_slice13/analysis/3daxis9.nii',
    '/space/zircon/5/users/kchai/I55_slice14/analysis/3daxis10.nii',
    '/space/zircon/5/users/kchai/I55_slice15/analysis/3daxis11.nii',
    '/space/zircon/5/users/kchai/I55_slice16/analysis/3daxis12.nii',
    '/space/zircon/5/users/kchai/I55_slice17/analysis/3daxis13.nii',
    '/space/zircon/5/users/kchai/I55_slice18/analysis/3daxis14.nii',
    '/space/zircon/5/users/kchai/I55_slice19/analysis/3daxis15.nii',
    '/space/zircon/5/users/kchai/I55_slice20/analysis/3daxis16.nii',
    '/space/zircon/5/users/kchai/I55_slice21/analysis/3daxis17.nii',
    '/space/zircon/5/users/kchai/I55_slice22/analysis/3daxis18.nii',
    '/space/zircon/5/users/kchai/I55_slice23/analysis/3daxis19.nii'
]

images = [nib.load(p).get_fdata() for p in tif_paths]

ref_image = nib.load('/autofs/space/nyx_002/users/tgong/Microstructure/data/I55_slab4/dmri.te1/dwi_biascorr_las.nii.gz')

# %%
images[0].shape
# Out:
# (8750, 3990, 3)

# %%
# %%
img_original = np.stack(images, axis=2)
# Out:
# (19, 8750, 3990, 3)

# %%
img_original.shape
# Out:
# (8750, 3990, 19, 3)

# %%
img=img_original

# %%
voxel_sizes = (0.01, 0.5, 0.01)  # in mm, which is 10, 10, 500 micron
img = img.transpose(1,2,0,3)
img = img[::-1,:,::-1,:]
affine = np.eye(4)
affine[0,0] = voxel_sizes[0]
affine[1,1] = voxel_sizes[1]
affine[2,2] = voxel_sizes[2]


img = np.where(mask[...,None], img, 0)
# %%

# %%
header= np.eye(4)
header[0,0] = voxel_sizes[0]
header[1,1] = voxel_sizes[1]
header[2,2] = voxel_sizes[2]
image = nib.Nifti1Image(img, header)

# %%
# %%
nib.save(align_centers_affine(image, ref_image), '/scratch/sub-I55_3daxis.nii')

# %%
# %%
nib.save(align_centers_affine(image, ref_image), '/scratch/sub-I55_3daxis.nii.gz')
